# %% [markdown]
# <a href="https://colab.research.google.com/github/YKulki/Turbulence-Modelling/blob/main/datasetGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path="/content/drive/MyDrive/Turbulence_data"
os.chdir(path)

# %%
di=np.zeros(shape=(1046,600,6))

# %%
def readfile(file_path,i):
  my_data=genfromtxt(file_path)
  my_data=np.delete(my_data,0,0)  #delete first row of each csv
  di[:,i,0]=i  
  di[:,i,1]=my_data[:,1]
  di[:,i,2]=my_data[:,2]              
  di[:,i,3]=my_data[:,3]
  di[:,i,4]=my_data[:,4]
  di[:,i,5]=my_data[:,5]

# %%
i=1
for file in sorted(os.listdir()):
  file_path=f'{path}/{file}'
  print(file_path)
  readfile(file_path,i)
  i=i+1
  if i>600:
    break
# Out:
# /content/drive/MyDrive/Turbulence_data/FFF-0601.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0602.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0603.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0604.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0605.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0606.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0607.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0608.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0609.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0610.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0611.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0612.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0613.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0614.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0615.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0616.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0617.csv
# /content/drive/MyDrive/Turbulence_data/FFF-0618.csv
# ...

# %%
di[0,:,0]

# %%
  np.save('data.npy',di)
